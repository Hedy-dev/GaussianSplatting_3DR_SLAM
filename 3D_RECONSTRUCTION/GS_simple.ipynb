# %%
# !nvidia-smi
# Out:
# Thu May  9 17:37:41 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# !git clone https://github.com/graphdeco-inria/gaussian-splatting --recursive
# Out:
# Cloning into 'gaussian-splatting'...
# remote: Enumerating objects: 734, done.
# remote: Total 734 (delta 0), reused 0 (delta 0), pack-reused 734
# Receiving objects: 100% (734/734), 2.13 MiB | 13.09 MiB/s, done.
# Resolving deltas: 100% (429/429), done.
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core.git) registered for path 'SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/gaussian-splatting/SIBR_viewers'...
# remote: Enumerating objects: 3150, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (179/179), done.
# remote: Total 3150 (delta 81), reused 0 (delta 0), pack-reused 2971
# ...

# %%
import torch
torch.__version__
# Out:
# '2.2.1+cu121'

# %%
# !pip install plyfile tqdm

# %%
# !ls
# Out:
# gaussian-splatting  sample_data

# %%
#/content/gaussian-splatting/submodules/diff-gaussian-rasterization
# !pip install gaussian-splatting/submodules/diff-gaussian-rasterization
# Out:
# Processing ./gaussian-splatting/submodules/diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff-gaussian-rasterization: filename=diff_gaussian_rasterization-0.0.0-cp310-cp310-linux_x86_64.whl size=3142337 sha256=2b1b424c72ac138b5e37bb360bcd31ee2a75fcf750c4ad0a7d6998a8e75adf6e
#   Stored in directory: /root/.cache/pip/wheels/e4/fd/3a/84782e92cd21de96696bbf2ba34361debad5701fa48bfe9e6b
# Successfully built diff-gaussian-rasterization
# ...

# %%
# !pip install gaussian-splatting/submodules/simple-knn
# Out:
# Processing ./gaussian-splatting/submodules/simple-knn
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for simple-knn: filename=simple_knn-0.0.0-cp310-cp310-linux_x86_64.whl size=2924387 sha256=faf149d2999e062589544b167f144328beb9f8e549713b8c00ff2372e2a23410
#   Stored in directory: /root/.cache/pip/wheels/81/d6/08/724a60e90d22d28442460572b541e07593de0440482e43701c
# Successfully built simple-knn
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/Diploma2/playground /playground

# %%
# !python /content/gaussian-splatting/train.py -s /playground --model_path /saving --save_iterations 7000 14000 21000 30000
# Out:
# 2024-05-09 17:53:16.506346: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-09 17:53:16.506397: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-09 17:53:16.507781: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-09 17:53:16.515023: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !zip -r /saving.zip /saving
# Out:
#   adding: saving/ (stored 0%)
#   adding: saving/input.ply (deflated 44%)
#   adding: saving/cfg_args (deflated 24%)
#   adding: saving/point_cloud/ (stored 0%)
#   adding: saving/point_cloud/iteration_14000/ (stored 0%)
#   adding: saving/point_cloud/iteration_14000/point_cloud.ply (deflated 15%)
#   adding: saving/point_cloud/iteration_21000/ (stored 0%)
#   adding: saving/point_cloud/iteration_21000/point_cloud.ply (deflated 16%)
#   adding: saving/point_cloud/iteration_7000/ (stored 0%)
#   adding: saving/point_cloud/iteration_7000/point_cloud.ply (deflated 17%)
#   adding: saving/point_cloud/iteration_30000/ (stored 0%)
#   adding: saving/point_cloud/iteration_30000/point_cloud.ply (deflated 16%)
#   adding: saving/events.out.tfevents.1715277200.4b370a632d41.6291.0 (deflated 29%)
#   adding: saving/events.out.tfevents.1715276681.4b370a632d41.4071.0 (deflated 9%)
#   adding: saving/cameras.json (deflated 68%)

# %%
# !cp /saving.zip /content/drive/MyDrive/Diploma2/playground
